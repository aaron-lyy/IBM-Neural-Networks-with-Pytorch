# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# <h1>Linear regression: Training and Validation Data</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to use learning rate hyperparameter to improve your model result.  .</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will learn to select the best learning rate by using validation data.</p>
#
# <ul>
#     <li><a href="#Makeup_Data">Make Some Data</a></li>
#     <li><a href="#LR_Loader_Cost">Create a Linear Regression Object, Data Loader and Criterion Function</a></li>
#     <li><a href="#LR_Hyper">Different learning rates and Data Structures to Store results for Different Hyperparameters</a></li>
#     <li><a href="#Model">Train different modules for different Hyperparameters</a></li>
#     <li><a href="#Result">View Results</a></li>
# </ul>
#
# <p>Estimated Time Needed: <strong>30 min</strong></p>
#
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries and set the random seed.

# %%
# Import libraries we need for this lab, and set the random seed

from torch import nn
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn,optim

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Makeup_Data">Make Some Data</h2>

# %% [markdown]
# First, we'll create some artificial data in a dataset class. The class will include the option to produce training data or validation data. The training data will include outliers.

# %%
# Create Data class

from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    
    # Constructor
    def __init__(self, train = True):
            self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
            self.f = -3 * self.x + 1
            self.y = self.f + 0.1 * torch.randn(self.x.size())
            self.len = self.x.shape[0]
            
            #outliers 
            if train == True:
                self.y[0] = 0
                self.y[50:55] = 20
            else:
                pass
      
    # Getter
    def __getitem__(self, index):    
        return self.x[index], self.y[index]
    
    # Get Length
    def __len__(self):
        return self.len

# %% [markdown]
# Create two objects: one that contains training data and a second that contains validation data. Assume that the training data has the outliers.

# %%
# Create training dataset and validation dataset

train_data = Data()
val_data = Data(train = False)

# %% [markdown]
# Overlay the training points in red over the function that generated the data. Notice the outliers at x=-3 and around x=2:

# %%
# Plot out training points

plt.plot(train_data.x.numpy(), train_data.y.numpy(), 'xr',label="training data ")
plt.plot(train_data.x.numpy(), train_data.f.numpy(),label="true function  ")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="LR_Loader_Cost">Create a Linear Regression Object,  Data Loader, and Criterion Function</h2>

# %%
# Create Linear Regression Class

from torch import nn

class linear_regression(nn.Module):
    
    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    # Prediction function
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# Create the criterion function and a <code>DataLoader</code> object:

# %%
# Create MSELoss function and DataLoader

criterion = nn.MSELoss()
trainloader = DataLoader(dataset = train_data, batch_size = 1)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="LR_Hyper">Different learning rates and Data Structures to Store results for different Hyperparameters</h2>

# %% [markdown]
# Create a list with different learning rates and a tensor (can be a list) for the training and validating cost/total loss. Include the list MODELS, which stores the training model for every value of the learning rate.

# %%
# Create Learning Rate list, the error lists and the MODELS list

learning_rates=[0.0001, 0.001, 0.01, 0.1]

train_error=torch.zeros(len(learning_rates))
validation_error=torch.zeros(len(learning_rates))

MODELS=[]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Model">Train different models  for different Hyperparameters</h2>

# %% [markdown]
# Try different values of learning rates, perform stochastic gradient descent, and save the results on the training data and validation data. Finally, save each model in a list.

# %%
# Define the train model function and train the model

def train_model_with_lr (iter, lr_list):
    
    # iterate through different learning rates 
    for i, lr in enumerate(lr_list):
        model = linear_regression(1, 1)
        optimizer = optim.SGD(model.parameters(), lr = lr)
        for epoch in range(iter):
            for x, y in trainloader:
                yhat = model(x)
                loss = criterion(yhat, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        # train data
        Yhat = model(train_data.x)
        train_loss = criterion(Yhat, train_data.y)
        train_error[i] = train_loss.item()
    
        # validation data
        Yhat = model(val_data.x)
        val_loss = criterion(Yhat, val_data.y)
        validation_error[i] = val_loss.item()
        MODELS.append(model)

train_model_with_lr(10, learning_rates)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Result">View the Results</h2>

# %% [markdown]
# Plot the training loss and validation loss for each learning rate:

# %%
# Plot the training loss and validation loss

plt.semilogx(np.array(learning_rates), train_error.numpy(), label = 'training loss/total Loss')
plt.semilogx(np.array(learning_rates), validation_error.numpy(), label = 'validation cost/total Loss')
plt.ylabel('Cost\ Total Loss')
plt.xlabel('learning rate')
plt.legend()
plt.show()

# %% [markdown]
# Produce a prediction by using the validation data for each model:

# %%
# Plot the predictions

i = 0
for model, learning_rate in zip(MODELS, learning_rates):
    yhat = model(val_data.x)
    plt.plot(val_data.x.numpy(), yhat.detach().numpy(), label = 'lr:' + str(learning_rate))
    print(i, yhat.detach().numpy()[0:3])
    i+=1
plt.plot(val_data.x.numpy(), val_data.f.numpy(), 'or', label = 'validation data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0 [[3.1776085]
#  [3.0941005]
#  [3.010592 ]]
# 1 [[5.902993 ]
#  [5.784539 ]
#  [5.6660852]]
# 2 [[6.6202087]
#  [6.485814 ]
#  [6.3514194]]
# 3 [[13.6292515]
#  [13.223826 ]
#  [12.8184   ]]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# The object <code>good_model</code> is the best performing model. Use the train loader to get the data samples x and y. Produce an estimate for <code>yhat</code> and print it out for every sample in a for a loop. Compare it to the actual prediction <code>y</code>.

# %%
good_model = MODELS[np.argmin(validation_error)]

for x,y in trainloader:
    print("Prediction: ",good_model(x), " Actual: ", y)
# Out:
# Prediction:  tensor([[13.6293]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[0.]])
# Prediction:  tensor([[13.2238]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[9.6136]])
# Prediction:  tensor([[12.8184]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[9.4232]])
# Prediction:  tensor([[12.4130]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[8.8640]])
# Prediction:  tensor([[12.0076]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[8.6784]])
# Prediction:  tensor([[11.6021]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[8.6220]])
# Prediction:  tensor([[11.1967]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[8.0546]])
# Prediction:  tensor([[10.7913]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[8.1679]])
# Prediction:  tensor([[10.3858]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[7.7288]])
# Prediction:  tensor([[9.9804]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[7.4096]])
# Prediction:  tensor([[9.5750]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[7.0607]])
# Prediction:  tensor([[9.1696]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[6.5228]])
# Prediction:  tensor([[8.7641]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[6.4131]])
# Prediction:  tensor([[8.3587]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[6.0685]])
# Prediction:  tensor([[7.9533]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[5.8320]])
# Prediction:  tensor([[7.5479]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[5.5685]])
# Prediction:  tensor([[7.1424]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[5.2460]])
# Prediction:  tensor([[6.7370]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[5.0212]])
# Prediction:  tensor([[6.3316]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[4.6682]])
# Prediction:  tensor([[5.9262]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[4.3100]])
# Prediction:  tensor([[5.5207]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[4.0518]])
# Prediction:  tensor([[5.1153]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[3.7225]])
# Prediction:  tensor([[4.7099]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[3.4462]])
# Prediction:  tensor([[4.3045]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[3.0650]])
# Prediction:  tensor([[3.8990]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[2.8165]])
# Prediction:  tensor([[3.4936]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[2.5833]])
# Prediction:  tensor([[3.0882]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[2.2058]])
# Prediction:  tensor([[2.6828]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[1.7737]])
# Prediction:  tensor([[2.2773]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[1.5986]])
# Prediction:  tensor([[1.8719]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[1.0859]])
# Prediction:  tensor([[1.4665]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[1.1760]])
# Prediction:  tensor([[1.0611]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[0.6794]])
# Prediction:  tensor([[0.6556]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[0.4830]])
# Prediction:  tensor([[0.2502]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[0.2322]])
# Prediction:  tensor([[-0.1552]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-0.1100]])
# Prediction:  tensor([[-0.5606]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-0.2319]])
# Prediction:  tensor([[-0.9661]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-0.7367]])
# Prediction:  tensor([[-1.3715]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-1.2566]])
# Prediction:  tensor([[-1.7769]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-1.4433]])
# Prediction:  tensor([[-2.1823]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-1.6063]])
# Prediction:  tensor([[-2.5878]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-2.0991]])
# Prediction:  tensor([[-2.9932]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-2.1933]])
# Prediction:  tensor([[-3.3986]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-2.6188]])
# Prediction:  tensor([[-3.8040]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-2.9229]])
# Prediction:  tensor([[-4.2095]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-3.1454]])
# Prediction:  tensor([[-4.6149]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-3.6089]])
# Prediction:  tensor([[-5.0203]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-3.8879]])
# Prediction:  tensor([[-5.4257]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-4.1199]])
# Prediction:  tensor([[-5.8312]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-4.5405]])
# Prediction:  tensor([[-6.2366]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-4.6450]])
# Prediction:  tensor([[-6.6420]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[20.]])
# Prediction:  tensor([[-7.0474]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[20.]])
# Prediction:  tensor([[-7.4529]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[20.]])
# Prediction:  tensor([[-7.8583]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[20.]])
# Prediction:  tensor([[-8.2637]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[20.]])
# Prediction:  tensor([[-8.6691]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-6.4453]])
# Prediction:  tensor([[-9.0746]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-6.9599]])
# Prediction:  tensor([[-9.4800]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-7.0246]])
# Prediction:  tensor([[-9.8854]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-7.5124]])
# Prediction:  tensor([[-10.2908]], grad_fn=<AddmmBackward0>)  Actual:  tensor([[-7.4974]])

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!--
# for x, y in trainloader:
#     print("yhat= ", model(x),"y", y)
# -->

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/registration/stepone?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork&context=cpdaas&apps=data_science_experience%2Cwatson_machine_learning"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork/Template/module%201/images/Watson_Studio.png"></a>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="www.linkedin.com/in/jiahui-mavis-zhou-a4537814a">Mavis Zhou</a>

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-23  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
